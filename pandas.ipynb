# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashronanki/pandas/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
https://pythonprogramming.net/correlation-table-python3-pandas-data-analysis/?completed=/groupby-python3-pandas-data-analysis/

# %%
import pandas as pd 
df = pd.read_csv("/content/avocado.csv")

# %%
#top n rows 
df.head(3)

# %%
#botton n rows 
df.tail(3)

# %%
# column data 
df["Date"].head()

# %%
reg = df[df["region"] == "Albany"]

# %%
reg.tail()
# Out:
#        Unnamed: 0       Date  AveragePrice  ...     type  year  region
# 17608           7 2018-02-04          1.52  ...  organic  2018  Albany
# 17609           8 2018-01-28          1.32  ...  organic  2018  Albany
# 17610           9 2018-01-21          1.54  ...  organic  2018  Albany
# 17611          10 2018-01-14          1.47  ...  organic  2018  Albany
# 17612          11 2018-01-07          1.54  ...  organic  2018  Albany
#
# [5 rows x 14 columns]

# %%
reg_year = reg.set_index("year")

# %%
# replace the same DF with index 
reg.set_index("Date", inplace= True)

# %%
reg.head( )

# %%
reg["AveragePrice"].plot()

# %%
# datatime converstion 
df["Date"]= pd.to_datetime(df["Date"])

# %%
reg.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume  ...          type  year  region
# Date                                                ...
# 2015-12-27           0          1.33      64236.62  ...  conventional  2015  Albany
# 2015-12-20           1          1.35      54876.98  ...  conventional  2015  Albany
# 2015-12-13           2          0.93     118220.22  ...  conventional  2015  Albany
# 2015-12-06           3          1.08      78992.15  ...  conventional  2015  Albany
# 2015-11-29           4          1.28      51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %%
reg.sort_index(inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reg["AveragePrice"].rolling(25).mean().plot()

# %%
reg["price25ma"] = reg["AveragePrice"].rolling(25).mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reg.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume  ...  year  region  price25ma
# Date                                                ...
# 2015-01-04          51          1.22      40873.28  ...  2015  Albany        NaN
# 2015-01-04          51          1.79       1373.95  ...  2015  Albany        NaN
# 2015-01-11          50          1.24      41195.08  ...  2015  Albany        NaN
# 2015-01-11          50          1.77       1182.56  ...  2015  Albany        NaN
# 2015-01-18          49          1.17      44511.28  ...  2015  Albany        NaN
#
# [5 rows x 14 columns]

# %%
df["region"].unique()

# %%
# list of items 
df["region"].values.tolist()

# %%
#set of the iteams 
set(df["region"].values.tolist())

# %%
# converting into list to itterate 
list(set(df["region"].values.tolist()))

# %%
graph_df = pd.DataFrame()

# %%
graph_df.head()
# Out:
#             Albany_price25ma  ...  GreatLakes_price25ma
# Date                          ...
# 2015-01-04               NaN  ...                   NaN
# 2015-01-04               NaN  ...                   NaN
# 2015-01-04               NaN  ...                   NaN
# 2015-01-04               NaN  ...                   NaN
# 2015-01-04               NaN  ...                   NaN
#
# [5 rows x 16 columns]

# %%
#reshape 
graph_df = pd.DataFrame() #doubt 

for region in df["region"].unique()[:16]:
  print(region)
  region_df = df.copy()[df["region"]== region]
  region_df.set_index("Date", inplace= True)
  region_df.sort_index(inplace=True)
  region_df[f"{region}_price25ma"] = reg["AveragePrice"].rolling(25).mean() # doubt 


  if graph_df.empty:
    graph_df = region_df[[f"{region}_price25ma"]]

  else:
    graph_df = graph_df.join(region_df[f"{region}_price25ma"])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
graph_df.tail()
# Out:
#             Albany_price25ma  ...  GreatLakes_price25ma
# Date                          ...
# 2018-03-25            1.4368  ...                1.4368
# 2018-03-25            1.4368  ...                1.4272
# 2018-03-25            1.4368  ...                1.4368
# 2018-03-25            1.4368  ...                1.4272
# 2018-03-25            1.4368  ...                1.4368
#
# [5 rows x 16 columns]

# %%
import pandas as pd

df = pd.read_csv("/content/avocado.csv")
df = df.copy()[df['type']=='organic']

df["Date"] = pd.to_datetime(df["Date"])

df.sort_values(by="Date", ascending=True, inplace=True)
df.head()
# Out:
#        Unnamed: 0       Date  AveragePrice  ...     type  year            region
# 9489           51 2015-01-04          1.24  ...  organic  2015        California
# 10269          51 2015-01-04          1.50  ...  organic  2015          LasVegas
# 10893          51 2015-01-04          1.12  ...  organic  2015     PhoenixTucson
# 9437           51 2015-01-04          1.73  ...  organic  2015  BuffaloRochester
# 11621          51 2015-01-04          1.30  ...  organic  2015           Spokane
#
# [5 rows x 14 columns]

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets! (so df rather than series)
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])

graph_df.tail()
# Out:
#             California_price25ma  ...  NewYork_price25ma
# Date                              ...
# 2018-02-25                1.9128  ...             1.9308
# 2018-03-04                1.8876  ...             1.9156
# 2018-03-11                1.8636  ...             1.9092
# 2018-03-18                1.8516  ...             1.8948
# 2018-03-25                1.8364  ...             1.8876
#
# [5 rows x 54 columns]

# %%
graph_df.dropna().plot(figsize=(8,5), legend=False)

# %% [markdown]
# Minimum Wage Data

# %%
df = pd.read_csv("/content/Minimum Wage Data.csv", encoding= "unicode_escape")

# %%
df.head(3)

# %%
df.to_csv("/content/mimwage.csv", encoding="utf-8")

# %%
df = pd.read_csv("/content/mimwage.csv")

# %%
#group by 
gb = df.groupby("state")

# %%
df.head()
# Out:
#    Year       State           Table_Data  ... CPI.Average  High.2018  Low.2018
# 0  1968     Alabama                  ...  ...   34.783333       0.00      0.00
# 1  1968      Alaska                 2.10  ...   34.783333      15.12     15.12
# 2  1968     Arizona  18.72 - 26.40/wk(b)  ...   34.783333       4.75      3.37
# 3  1968    Arkansas          1.25/day(b)  ...   34.783333       1.12      1.12
# 4  1968  California              1.65(b)  ...   34.783333      11.88     11.88
#
# [5 rows x 9 columns]

# %%
gb = df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#         State Table_Data Footnote  ...  CPI.Average  High.2018  Low.2018
# Year                               ...
# 1968  Alabama        ...      NaN  ...    34.783333        0.0       0.0
# 1969  Alabama        ...      NaN  ...    36.683333        0.0       0.0
# 1970  Alabama        ...      NaN  ...    38.825000        0.0       0.0
# 1971  Alabama        ...      NaN  ...    40.491667        0.0       0.0
# 1972  Alabama        ...      NaN  ...    41.816667        0.0       0.0
#
# [5 rows x 8 columns]

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  ...  West Virginia  Wisconsin  Wyoming
# Year                            ...
# 1968      0.0   15.12     3.37  ...           7.20       9.00     8.64
# 1969      0.0   14.33     3.19  ...           6.83       8.53     8.19
# 1970      0.0   13.54     3.02  ...           6.45       8.38     8.38
# 1971      0.0   12.99     2.89  ...           6.18       8.04     8.04
# 1972      0.0   12.57     2.80  ...           7.19       8.68     8.98
#
# [5 rows x 55 columns]

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona  ...  West Virginia  Wisconsin    Wyoming
# count     50.0  50.000000  50.000000  ...      50.000000  50.000000  50.000000
# mean       0.0   9.583800   2.316200  ...       7.166400   7.694200   5.149200
# std        0.0   1.845176   3.474504  ...       0.793673   0.762675   1.998928
# min        0.0   7.380000   0.000000  ...       5.580000   6.420000   2.260000
# 25%        0.0   8.252500   0.000000  ...       6.630000   7.107500   3.270000
# 50%        0.0   8.890000   0.000000  ...       7.075000   7.580000   5.445000
# 75%        0.0  10.492500   3.147500  ...       7.612500   8.145000   6.607500
# max        0.0  15.120000  10.220000  ...       9.130000   9.660000   8.980000
#
# [8 rows x 55 columns]

# %%
#corelation
act_min_wage.corr()

# %%
issue_df = df[df['Low.2018']==0]

issue_df.head()
# Out:
#     Year     State Table_Data  ... CPI.Average  High.2018  Low.2018
# 0   1968   Alabama        ...  ...   34.783333        0.0       0.0
# 10  1968   Florida        ...  ...   34.783333        0.0       0.0
# 11  1968   Georgia        ...  ...   34.783333        0.0       0.0
# 15  1968  Illinois        ...  ...   34.783333        0.0       0.0
# 17  1968      Iowa        ...  ...   34.783333        0.0       0.0
#
# [5 rows x 9 columns]

# %%
import numpy as np

# %%
act_min_wage.replace(0,np.NaN).dropna(axis=1).corr().head()
# Out:
#                Alaska  Arkansas  California  ...  West Virginia  Wisconsin   Wyoming
# Alaska       1.000000 -0.377934    0.717653  ...       0.044814   0.702570  0.727932
# Arkansas    -0.377934  1.000000   -0.234367  ...       0.420819   0.000470 -0.250592
# California   0.717653 -0.234367    1.000000  ...       0.371765   0.584067  0.722617
# Colorado    -0.129332  0.135749    0.483313  ...       0.533623   0.011501  0.130053
# Connecticut  0.680886  0.047580    0.876215  ...       0.400099   0.585790  0.814971
#
# [5 rows x 39 columns]

# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()
#Now let's see if any of the identified problems exist after we've dropped:

for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("Missing something here....")

# %%
grouped_issues = issue_df.groupby("State")

grouped_issues.get_group("Alabama").head(3)
# Out:
#      Year    State Table_Data  ... CPI.Average  High.2018  Low.2018
# 0    1968  Alabama        ...  ...   34.783333        0.0       0.0
# 55   1969  Alabama        ...  ...   36.683333        0.0       0.0
# 110  1970  Alabama        ...  ...   38.825000        0.0       0.0
#
# [3 rows x 9 columns]

# %%
grouped_issues.get_group("Alabama")['Low.2018'].sum()
# Out:
# 0.0

# %%
for state, data in grouped_issues:
    if data['Low.2018'].sum() != 0.0:
        print("Some data found for", state)

# %%
import matplotlib.pyplot as plt
plt.matshow(min_wage_corr)

# %%
min_wage_corr.head(2)
# Out:
#             Alaska  Arkansas  California  ...  West Virginia  Wisconsin   Wyoming
# Alaska    1.000000 -0.377934    0.717653  ...       0.044814    0.70257  0.727932
# Arkansas -0.377934  1.000000   -0.234367  ...       0.420819    0.00047 -0.250592
#
# [2 rows x 39 columns]

# %%
labels = [c[:2] for c in min_wage_corr.columns]
fig  = plt.figure(figsize=(12,22))
ax = fig.add_subplot(111)
ax.set_xticks
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)

# %%
labels = [c[:2] for c in min_wage_corr.columns]  # get abbv state names.

fig = plt.figure(figsize=(12,12))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()

# %%
import requests

web = requests.get("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
dfs = pd.read_html(web.text)

# %%
web.text

# %%
dfs

# %%
import pandas as pd

# https://www.infoplease.com/state-abbreviations-and-state-postal-codes

dfs = pd.read_html("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
for df in dfs:
    print(df.head())

# %%
state_abbv = dfs[0]

state_abbv.head()
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA

# %%
state_abbv.to_csv("/content/state_abbv.csv")

# %%
state_abbv = pd.read_csv("/content/state_abbv.csv", index_col=0)
state_abbv.head()

# %%
abbv_dict = state_abbv.to_dict()
abbv_dict
# Out:
# {'Abbreviation': {0: 'Ala.',
#   1: 'Alaska',
#   2: 'Ariz.',
#   3: 'Ark.',
#   4: 'Calif.',
#   5: 'Colo.',
#   6: 'Conn.',
#   7: 'Del.',
#   8: 'D.C.',
#   9: 'Fla.',
#   10: 'Ga.',
#   11: 'Hawaii',
#   12: 'Idaho',
#   13: 'Ill.',
#   14: 'Ind.',
#   15: 'Iowa',
#   16: 'Kans.',
#   17: 'Ky.',
#   18: 'La.',
#   19: 'Maine',
#   20: 'Md.',
#   21: 'Mass.',
#   22: 'Mich.',
#   23: 'Minn.',
#   24: 'Miss.',
#   25: 'Mo.',
#   26: 'Mont.',
#   27: 'Nebr.',
#   28: 'Nev.',
#   29: 'N.H.',
#   30: 'N.J.',
#   31: 'N.M.',
#   32: 'N.Y.',
#   33: 'N.C.',
#   34: 'N.D.',
#   35: 'Ohio',
#   36: 'Okla.',
#   37: 'Ore.',
#   38: 'Pa.',
#   39: 'R.I.',
#   40: 'S.C.',
#   41: 'S.D.',
#   42: 'Tenn.',
#   43: 'Tex.',
#   44: 'Utah',
#   45: 'Vt.',
#   46: 'Va.',
#   47: 'Wash.',
#   48: 'W.Va.',
#   49: 'Wis.',
#   50: 'Wyo.'},
#  'Postal Code': {0: 'AL',
#   1: 'AK',
#   2: 'AZ',
#   3: 'AR',
#   4: 'CA',
#   5: 'CO',
#   6: 'CT',
#   7: 'DE',
#   8: 'DC',
#   9: 'FL',
#   10: 'GA',
# ...

# %%
abbv_dict = abbv_dict['Postal Code']
abbv_dict
# Out:
# {0: 'AL',
#  1: 'AK',
#  2: 'AZ',
#  3: 'AR',
#  4: 'CA',
#  5: 'CO',
#  6: 'CT',
#  7: 'DE',
#  8: 'DC',
#  9: 'FL',
#  10: 'GA',
#  11: 'HI',
#  12: 'ID',
#  13: 'IL',
#  14: 'IN',
#  15: 'IA',
#  16: 'KS',
#  17: 'KY',
#  18: 'LA',
#  19: 'ME',
#  20: 'MD',
#  21: 'MA',
#  22: 'MI',
#  23: 'MN',
#  24: 'MS',
#  25: 'MO',
#  26: 'MT',
#  27: 'NE',
#  28: 'NV',
#  29: 'NH',
#  30: 'NJ',
#  31: 'NM',
#  32: 'NY',
#  33: 'NC',
#  34: 'ND',
#  35: 'OH',
#  36: 'OK',
#  37: 'OR',
#  38: 'PA',
#  39: 'RI',
#  40: 'SC',
#  41: 'SD',
#  42: 'TN',
#  43: 'TX',
#  44: 'UT',
#  45: 'VT',
#  46: 'VA',
#  47: 'WA',
#  48: 'WV',
#  49: 'WI',
#  50: 'WY'}

# %%
labels = [abbv_dict[c] for c in min_wage_corr.columns]

# %% [markdown]
# #Pokemon with stats

# %%
import pandas as pd

# %%
poke = pd.read_csv("/content/Pokemon.csv")

# %%
poke.head(2)
# Out:
#    #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2    Ivysaur  Grass  Poison  ...       80     60           1      False
#
# [2 rows x 13 columns]

# %%
poke.tail(3)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [3 rows x 13 columns]

# %% [markdown]
# # separated file using delimiter

# %%
# tab separated file 
x = pd.read_csv("xyz", delimiter="\t")

# %% [markdown]
# # data type

# %%
# data type 
poke.dtypes

# %% [markdown]
# # reading Header

# %%
# reading Header 
poke.columns
poke.index rangeIndex(start=0, stop=800, step=1)

# %% [markdown]
# # read each column

# %%
# read each column 
poke["Name"][0:5] # zero to 5 rows 
poke[["Name","HP"]][15:25] # multiple columns with  specific range 
poke.Name # not recommmend but it works 
poke.HP[0:5]
# Out:
# 0    45
# 1    60
# 2    80
# 3    80
# 4    39
# Name: HP, dtype: int64

# %% [markdown]
# #read rach row

# %%
#read rach row 
poke.iloc[0:4] # using location

# %% [markdown]
# # Read a specific location (Row , column )

# %%
# Read a specific location (Row , column )

poke.iloc[2,1]

poke['Name'].loc[4]
# Out:
# 'Venusaur'

# %% [markdown]
# # loc function to filter specific items

# %%
# loc function to filter specific items 
poke.loc[poke["Type 1"]=="Fire"]
poke.loc[poke["Name"]== "Tepig"]

poke.loc[poke["HP"]== int("62")]  # for a integer use int()

# %% [markdown]
# #itterate through row

# %%
# itterate through row 
for index, row in poke.iterrows():  # how to specifi a range    print(index,row[0:5])
  print(index,row["Name"][0:5]) # position parameter is not working

# %%
for row in poke.iloc[5:10].iterrows():  
  print(row)

# %% [markdown]
# #describe

# %%
#describe 
poke.describe()
# Out:
#                 #      Total          HP  ...     Sp. Def       Speed  Generation
# count  800.000000  800.00000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750  435.10250   69.258750  ...   71.902500   68.277500     3.32375
# std    208.343798  119.96304   25.534669  ...   27.828916   29.060474     1.66129
# min      1.000000  180.00000    1.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000  330.00000   50.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000  450.00000   65.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000  515.00000   80.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  780.00000  255.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 9 columns]

# %% [markdown]
# #checking Nan values

# %%
# checking Nan values 
poke.isnull()# true impilicts null value 
#null = pd.isnull(poke["Type 2"])  # find the nulls of column

# %%
poke[null]

# %% [markdown]
# # drop Duplicates and Na

# %%
# drop Duplicates and Na
poke.dropna
poke.drop_duplicates
poke = poke.drop(columns="total0")

# %% [markdown]
# # sorting

# %%
#poke.sort_values("HP", ascending= False)
#poke.sort_values("Name", ascending= False) # bottom to top
#poke.sort_values(["Name","HP"], ascending= False) 
poke.sort_values(["Name","HP"], ascending=[1,0]) #

# %% [markdown]
# # make chnages to the Data

# %%
poke.tail()
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 795  719              Diancie     Rock  ...    50           6       True
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [5 rows x 14 columns]

# %%
# adding row 
poke["Total2"] = poke["HP"]+ poke["Attack"]+poke["Defense"]+poke["Sp. Atk"]+poke["Sp. Def"]+poke["Speed"]
# poke["total2"] = poke.iloc[:, 5:11].sum(axis=1) # with out axis it wont be adding 
# poke["total0"] = poke.iloc[:, 5:11].sum(axis=0) # NaN values

# %%
# drop 
poke = poke.drop(columns="total0") # when you drop a column or row  reasign the Df

# %% [markdown]
# # Rearrange the Columns

# %%
cols = list(poke.columns) # array of columns

# %%
poke = poke[cols[0:5]+ [cols[-1]]+ cols[5:13]]

# %%
cols

# %%
cols[0:5]+ [cols[-1]]+ cols[5:13]

# %% [markdown]
# # saving the data to new csv ,xlsx, txt, dict

# %%
poke.to_csv("/content/modified.csv")
#poke.to_csv("/content/modified.csv",index= False) with out the index

# %%
poke.to_excel("/content/modified_poke.xlsx", index = False)

# %%
df_xlsx = pd.read_excel("/content/modified_poke.xlsx")

# %%
df_xlsx.head(4)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [4 rows x 14 columns]

# %%
poke.to_csv("/content/tabsep.txt",index= False, sep= "\t")

# %% [markdown]
# #Filtering

# %%
df = pd.read_csv("/content/modified.csv")

# %%
df.head(2)

# %%
df[df["Type 1"]=="Grass"] # one condition

# %%
df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]== "Poison")] # using and condition

# %%
new_and = df.loc[(df["Type 1"]=="Grass") | (df["Type 2"]== "Poison")] # or condition

# %%
new_df = df.loc[(df["Type 1"]=="Grass") & (df["Type 2"]== "Poison") & (df['HP'] >70)]

# %% [markdown]
# #Reset Index

# %%
new_df = new_df.reset_index()

# %%
new_df

# %%
new_df.reset_index(drop=True, inplace=True) # drops the old index

# %%
new_df

# %%
new_and.columns
# Out:
# Index(['index', 'Unnamed: 0', '#', 'Name', 'Type 1', 'Type 2', 'Total',
#        'Total2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed',
#        'Generation', 'Legendary'],
#       dtype='object')

# %%
new_and = new_and.reset_index(drop=True)

# %%
new_and = new_and.drop(columns=["Unnamed: 0","index"], axis= 1)

# %%
new_and
# Out:
#       #                   Name Type 1  ... Speed  Generation  Legendary
# 0     1              Bulbasaur  Grass  ...    45           1      False
# 1     2                Ivysaur  Grass  ...    60           1      False
# 2     3               Venusaur  Grass  ...    80           1      False
# 3     3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4    13                 Weedle    Bug  ...    50           1      False
# ..  ...                    ...    ...  ...   ...         ...        ...
# 84  650                Chespin  Grass  ...    38           6      False
# 85  651              Quilladin  Grass  ...    57           6      False
# 86  652             Chesnaught  Grass  ...    64           6      False
# 87  672                 Skiddo  Grass  ...    52           6      False
# 88  673                 Gogoat  Grass  ...    68           6      False
#
# [89 rows x 14 columns]

# %% [markdown]
# #conditions  & Regex

# %%
df[df["Name"].str.contains("Mega")]  # retuurn the valus contain Mega

# %%
# reverser of it NOT 
df[~df["Name"].str.contains("Mega")]  # not mega

# %%
df[df["Name"].str.contains("Mega|mega")] # bot Mega and mega case sensitive

# %%
import re

# %%
df[df["Name"].str.contains("Mega|mega", regex= True)]

# %%
df[df["Type 1"].str.contains("grass|fire", flags = re.IGNORECASE, regex= True)] # ingnore Cases

# %%
#df[df["Name"].str.contains("pi",flags=re.I,regex= True)] # gives all the name containing PI 
df[df["Name"].str.contains("^pi[a-z]*",flags=re.I,regex= True)]
# Out:
#      Unnamed: 0    #                 Name  ... Speed Generation  Legendary
# 20           20   16               Pidgey  ...    56          1      False
# 21           21   17            Pidgeotto  ...    71          1      False
# 22           22   18              Pidgeot  ...   101          1      False
# 23           23   18  PidgeotMega Pidgeot  ...   121          1      False
# 30           30   25              Pikachu  ...    90          1      False
# 136         136  127               Pinsir  ...    85          1      False
# 137         137  127    PinsirMega Pinsir  ...   105          1      False
# 186         186  172                Pichu  ...    60          2      False
# 219         219  204               Pineco  ...    15          2      False
# 239         239  221            Piloswine  ...    50          2      False
# 438         438  393               Piplup  ...    40          4      False
# ...

# %% [markdown]
# #change/replace cells

# %%
df.loc[df["Type 1"]=="Flamer","Type 1"] = "Fire"

# %%
df.loc[df["Total"]>500,["Generation","Legendary"]] = "test" # replacing the original value with Test

# %%
df.loc[df["Total"]>500,["Generation","Legendary"]] = ["test","test2"] #passing individual values

# %%
df

# %% [markdown]
# #Group By (Aggregate States)

# %%
df

# %%
df = pd.read_csv("/content/Pokemon.csv")

# %%
df.groupby(["Type 1"]).mean()

# %%
df.groupby(["Type 1"]).mean().sort_values("Defense", ascending= False)

# %%
df.groupby(["Type 1"]).mean().sort_values("Attack", ascending= False)

# %%
df.groupby(["Type 1"]).count() # count of types

# %%
df["count"] = 1

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Speed  Generation  Legendary  count
# 0  1              Bulbasaur  Grass  Poison  ...     45           1      False      1
# 1  2                Ivysaur  Grass  Poison  ...     60           1      False      1
# 2  3               Venusaur  Grass  Poison  ...     80           1      False      1
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...     80           1      False      1
# 4  4             Charmander   Fire     NaN  ...     65           1      False      1
#
# [5 rows x 14 columns]

# %%
df.groupby(["Type 1"]).count()["HP"]

# %%
df.groupby(["Type 1"]).count()["count"]

# %%
# two columns 
compressed = df.groupby(["Type 1","Type 2"]).count()

# %%
compressed

# %% [markdown]
# #working with Large Datasets

# %%
con_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv("/content/Pokemon.csv", chunksize= 5):
  results = df.groupby(["Type 1"]).count()
  con_df = pd.concat([con_df, results])
  #print(df)

# %%
con_df
# Out:
#          # Name Type 1 Type 2 Total  ... Sp. Atk Sp. Def Speed Generation Legendary
# Fire     1    1    NaN      0     1  ...       1       1     1          1         1
# Grass    4    4    NaN      4     4  ...       4       4     4          4         4
# Fire     4    4    NaN      3     4  ...       4       4     4          4         4
# Water    1    1    NaN      0     1  ...       1       1     1          1         1
# Bug      2    2    NaN      0     2  ...       2       2     2          2         2
# ...     ..  ...    ...    ...   ...  ...     ...     ...   ...        ...       ...
# Fairy    1    1    NaN      0     1  ...       1       1     1          1         1
# Flying   2    2    NaN      2     2  ...       2       2     2          2         2
# Fire     1    1    NaN      1     1  ...       1       1     1          1         1
# Psychic  2    2    NaN      2     2  ...       2       2     2          2         2
# ...

# %%
df.loc[df["Name"]== "Bulbasaur"]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []
