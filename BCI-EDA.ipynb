# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/avinashronanki/Desktop/bci/shivaji_sample_test_conversation_museMonitor_2021-07-23--22-03-09_4090529662605628899.csv")

# %%
df
# Out:
#                   TimeStamp  Delta_TP9  Delta_AF7  Delta_AF8  Delta_TP10  \
# 0   2021-07-23 22:03:09.052   0.883967   0.012309   0.434136    1.194394
# 1   2021-07-23 22:03:10.097   0.763916   0.130218   0.519549    1.091708
# 2   2021-07-23 22:03:11.105   0.202329   0.055726   0.033369    0.886161
# 3   2021-07-23 22:03:12.130   0.570379  -0.027967   0.096643    0.553629
# 4   2021-07-23 22:03:13.145   1.140695   0.476031   0.547788    0.786597
# ..                      ...        ...        ...        ...         ...
# 193 2021-07-23 22:06:08.616   0.813166  -0.025891   0.252222    0.808815
# 194 2021-07-23 22:06:09.628   1.134373  -0.031090   0.331754    0.950249
# 195 2021-07-23 22:06:10.668   0.992267  -0.427155  -0.146408    0.920694
# 196 2021-07-23 22:06:11.697   0.992267  -0.427155  -0.146408    0.920694
# 197 2021-07-23 22:06:12.705   0.992267  -0.427155  -0.146408    0.920694
#
#      Theta_TP9  Theta_AF7  Theta_AF8  Theta_TP10  Alpha_TP9  ...    Gyro_X  \
# ...

# %%
df.columns
# Out:
# Index(['TimeStamp', 'Delta_TP9', 'Delta_AF7', 'Delta_AF8', 'Delta_TP10',
#        'Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10', 'Alpha_TP9',
#        'Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10', 'Beta_TP9', 'Beta_AF7',
#        'Beta_AF8', 'Beta_TP10', 'Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8',
#        'Gamma_TP10', 'RAW_TP9', 'RAW_AF7', 'RAW_AF8', 'RAW_TP10', 'AUX_RIGHT',
#        'Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z', 'Gyro_X',
#        'Gyro_Y', 'Gyro_Z', 'HeadBandOn', 'HSI_TP9', 'HSI_AF7', 'HSI_AF8',
#        'HSI_TP10', 'Battery', 'Elements'],
#       dtype='object')

# %%
# eliminating the rows which are blank
df = df[df.Elements != "/muse/elements/blink"]

# %%
df['TimeStamp'] = pd.to_datetime(df['TimeStamp'],format="%Y-%m-%d %H:%M:%S")

# %%
#Delta analysis 
df_delta = df[['Delta_TP9', 'Delta_AF7','Delta_AF8','Delta_TP10']]

# %%
df_delta
# Out:
#         Delta_TP9   Delta_AF7    Delta_AF8    Delta_TP10
# 0        0.883967    0.012309     0.434136      1.194394
# 1        2.531851    0.154835     1.387821      3.480497
# 2        4.382064    0.353088     2.374875      6.652761
# 3        6.802656    0.523373     3.458572     10.378654
# 4       10.363942    1.169689     5.090057     14.891143
# ..            ...         ...          ...           ...
# 193  10074.858756 -693.733754  1319.783330  10041.547811
# 194  10184.930304 -709.950758  1327.905996  10147.781619
# 195  10295.994118 -726.594918  1335.882254  10254.936122
# 196  10408.050199 -743.666232  1343.712104  10363.011319
# 197  10521.098546 -761.164702  1351.395546  10472.007210
#
# [181 rows x 4 columns]

# %%
df_delta.plot()
# Out:
# <AxesSubplot:>

# %%
df_delta.diff().hist(color="k", alpha=0.5, bins=50);

# %%
#Theta 

df_Theta = df[['Theta_TP9', 'Theta_AF7','Theta_AF8','Theta_TP10']]

# %%
# df_Theta = df_Theta.cumsum()
# plt.figure()
df_Theta.plot()
# Out:
# <AxesSubplot:>

# %%
df_Theta.diff().hist(color="k", alpha=0.5, bins=50);

# %%
#Alpha 
df_Alpha = df[['Alpha_TP9', 'Alpha_AF7','Alpha_AF8','Alpha_TP10']]

# %%
# df_Alpha = df_Alpha.cumsum()
# plt.figure()
df_Alpha.plot()
# Out:
# <AxesSubplot:>

# %%
df_Alpha = df_Alpha.cumsum()
plt.figure()
df_Alpha.plot()
# Out:
# <AxesSubplot:>

# %%
df_Alpha.diff().hist(color="k", alpha=0.5, bins=50);

# %%
df_Beta = df[['Beta_TP9', 'Beta_AF7','Beta_AF8','Beta_TP10']]

# %%
df_Beta.plot()
# Out:
# <AxesSubplot:>

# %%
df_Beta = df_Beta.cumsum()
plt.figure()
df_Beta.plot()
# Out:
# <AxesSubplot:>

# %%
df_Beta.diff().hist(color="k", alpha=0.5, bins=50);

# %%
df_Gamma = df[['Gamma_TP9', 'Gamma_AF7','Gamma_AF8','Gamma_TP10']]

# %%
df_Gamma.plot()
# Out:
# <AxesSubplot:>

# %%
df_Gamma = df_Gamma.cumsum()
plt.figure()
df_Gamma.plot()
# Out:
# <AxesSubplot:>

# %%
df_Gamma.diff().hist(color="k", alpha=0.5, bins=50);

# %%
#Raw
df_RAW = df[['RAW_TP9', 'RAW_AF7','RAW_AF8','RAW_TP10']]

# %%
df_RAW.plot()
# Out:
# <AxesSubplot:>

# %%
df_RAW = df_RAW.cumsum()
plt.figure()
df_RAW.plot()
# Out:
# <AxesSubplot:>

# %%
df_RAW
# Out:
#           RAW_TP9       RAW_AF7       RAW_AF8      RAW_TP10
# 0       802.23444     803.84610     808.68134     814.72530
# 1      1589.96338    1608.49814    1614.94507    1604.87185
# 2      2397.83888    2422.01464    2424.83521    2422.01475
# 3      3194.02938    3233.91944    3231.90481    3231.90489
# 4      3991.42868    4039.78024    4038.57151    4036.95982
# ..            ...           ...           ...           ...
# 193  141992.67527  142547.10673  142458.05956  142337.18091
# 194  142794.50677  143352.16166  143257.87639  143153.51791
# 195  143601.97930  144156.00776  144063.73719  143966.63141
# 196  144409.45183  144959.85386  144869.59799  144779.74491
# 197  145216.92436  145763.69996  145675.45879  145592.85841
#
# [181 rows x 4 columns]

# %%
df_RAW.diff().hist(color="k", alpha=0.5, bins=50);

# %%
df_RAW_AF7 = df[['RAW_AF7']]

# %%
df_RAW_AF7.plot()
# Out:
# <AxesSubplot:>
